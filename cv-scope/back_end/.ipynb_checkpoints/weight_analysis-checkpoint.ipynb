# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
from gradcam import *
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, LeakyReLU, ZeroPadding2D, BatchNormalization, MaxPool2D,\
                                    Cropping2D, UpSampling2D, Add, Softmax, Conv2DTranspose, concatenate,\
                                    GlobalAveragePooling2D, Reshape, Dense, Permute, multiply, ReLU
from tensorflow.keras.activations import sigmoid as Sigmoid
from tensorflow.keras.regularizers import l2

tf.random.set_seed(0)
gpus = tf.config.experimental.list_physical_devices('GPU')
if len(gpus) > 0:
    print(f'GPUs {gpus}')
    tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# 2022-11-15 23:23:54.170252: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2022-11-15 23:23:55.372095: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-15 23:23:55.372706: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-11-15 23:23:55.468679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-15 23:23:55.469153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti computeCapability: 7.5
# ...

# %%
from model import *
# Out:
# 2022-11-16 02:50:59.069228: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2022-11-16 02:51:00.076618: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-16 02:51:00.077230: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-11-16 02:51:00.132303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 02:51:00.132681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti computeCapability: 7.5
# ...

# %%
model , layers = get_model(model_name='resnetv2_50')
# Out:
# 2022-11-16 02:51:12.773712: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-16 02:51:12.773865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-16 02:51:12.774175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-11-16 02:51:12.774214: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-11-16 02:51:12.774247: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# ...

# %%
img = cv2.imread('data/imgs/car/1.jpg')

# %%
img = cv2.imencode('.jpg',img)

# %%
img
# Out:
# (True,
#  array([[255],
#         [216],
#         [255],
#         ...,
#         [161],
#         [255],
#         [217]], dtype=uint8))

# %%
import io
out = io.BytesIO(np.array([10]))

# %%
out.read()
# Out:
# b'\n\x00\x00\x00\x00\x00\x00\x00'

# %%
import io
buf = io.BytesIO(img[1])

# %%
plt = plot_layer_fmaps(model,'conv5_block3_out')
# Out:
# 2022-11-16 02:51:24.712480: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2022-11-16 02:51:26.355765: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2022-11-16 02:51:26.418421: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-11-16 02:51:27.499235: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2022-11-16 02:51:27.499944: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11

# %%
def get_model(model_name='resnet_v2_50'):
    if model_name == 'resnet_v2_50':
        from applications.resnet_v2 import ResNet50V2
        model = ResNet50V2(include_top=True,
                     weights='imagenet',
                     input_tensor=None,
                     input_shape=(256,256,3),
                     pooling=None,
                     classes=1000)
        layers = [layer.name for layer in model.layers]
    if model_name == 'mobilenet_v2':
        from applications.mobilenet_v2 import MobileNetV2
        model = MobileNetV2(include_top=True,
                     alpha   = 1.0,
                     weights ='imagenet',
                     input_tensor = None,
                     input_shape  = (256,256,3),
                     pooling = None,
                     classes = 1000)
        layers = [layer.name  for layer in model.layers]
    return model,layers

# %%
model,layers = get_model(model_name='resnet_v2_50')
# Out:
# 2022-11-15 23:23:55.541937: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-11-15 23:23:55.542162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-15 23:23:55.542406: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1660 Ti computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 24 deviceMemorySize: 5.80GiB deviceMemoryBandwidth: 268.26GiB/s
# 2022-11-15 23:23:55.542456: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2022-11-15 23:23:55.542491: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# ...

# %%
for layer in model.layers:
    shapes=[]
    for var in layer.trainable_variables:
        shapes += [var.numpy().shape]
        
    if len(shapes): print(layer.name,'\n',shapes)
    else: print(layer.name)
# Out:
# input_1
# conv1_pad
# conv1_conv
#  [(7, 7, 3, 64), (64,)]
# pool1_pad
# pool1_pool
# conv2_block1_preact_bn
#  [(64,), (64,)]
# conv2_block1_preact_relu
# conv2_block1_1_conv
#  [(1, 1, 64, 64)]
# conv2_block1_1_bn
#  [(64,), (64,)]
# conv2_block1_1_relu
# conv2_block1_2_pad
# conv2_block1_2_conv
#  [(3, 3, 64, 64)]
# conv2_block1_2_bn
#  [(64,), (64,)]
# conv2_block1_2_relu
# conv2_block1_0_conv
#  [(1, 1, 64, 256), (256,)]
# conv2_block1_3_conv
#  [(1, 1, 64, 256), (256,)]
# conv2_block1_out
# conv2_block2_preact_bn
#  [(256,), (256,)]
# conv2_block2_preact_relu
# conv2_block2_1_conv
#  [(1, 1, 256, 64)]
# conv2_block2_1_bn
#  [(64,), (64,)]
# conv2_block2_1_relu
# conv2_block2_2_pad
# conv2_block2_2_conv
#  [(3, 3, 64, 64)]
# conv2_block2_2_bn
#  [(64,), (64,)]
# conv2_block2_2_relu
# conv2_block2_3_conv
#  [(1, 1, 64, 256), (256,)]
# conv2_block2_out
# conv2_block3_preact_bn
#  [(256,), (256,)]
# conv2_block3_preact_relu
# conv2_block3_1_conv
#  [(1, 1, 256, 64)]
# ...

# %%
model.layers[2].trainable_variables[1].shape
# Out:
# TensorShape([64])

# %%
## model.save('../data/resnet50.hdf5')

# %%
def b2r(x):
    return cv2.cvtColor(x,cv2.COLOR_BGR2RGB)

def get_img_array(img_path, size=(256,256)):
    img = cv2.imread(img_path)
    img = b2r(img)
    img = cv2.resize(img,size)
    return img

last_conv_layer_name = 'conv_6'
pred_index = 0
path = '../data/imgs/train/1.jpg' 
img = get_img_array(path)

path = '../data/imgs/car/1.jpg' 
img = get_img_array(path)
plt.imshow(img)

def plot_fmap(_arr):
    N = _arr.shape[-1]
    m = int(np.sqrt(N))
    n = N//m
    feat_size = _arr.shape[0]
    temp = np.zeros((feat_size*m-1,feat_size*n-1))
    for i in range(0,m-1):
        for j in range(0,n-1):
            #print(i,j,i*m+j)
            temp[i*feat_size:(i+1)*feat_size,j*feat_size:(j+1)*feat_size] = _arr[:,:,i*m+j]#/arr[:,:,i*m+j].max()
    fig = plt.figure(figsize=(10,10))
    plt.imshow(temp)
    plt.xticks(range(0,feat_size*m-1,feat_size),rotation=90)
    plt.yticks(range(0,feat_size*m-1,feat_size),rotation=0)
    plt.grid(linewidth=0.3)
    
lyrs = ['conv2_block3_out','conv3_block3_out','conv4_block3_out','conv5_block3_out']
def plot_layer_fmaps(conv_layer_name):
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(conv_layer_name).output, model.output])
    img_array = img[np.newaxis,:,:,:]/255.0
    arr,preds = grad_model(img_array)
    plot_fmap(arr[0])

# %%
plot_layer_fmaps(lyrs[-2])

# %%
input_details
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 input_details
#
# NameError: name 'input_details' is not defined

# %%
#https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
#!cd ../data && wget https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.5_224.h5

# %%
import tflite2onnx
import tensorflow as tf
tflite_file = '../data/ssd_mobilenet_v1_1_metadata_1.tflite'
onnx_file   = '../data/ssd_mobilenet_v1_1_metadata_1.onnx'

tflite2onnx.convert(tflite_file,onnx_file)

# %%
tflite2onnx.s

# %%
tflite2onnx.getSupportedOperators()
